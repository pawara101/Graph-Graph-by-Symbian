# %% [markdown]
# ## Version checks on G_G

# %%
import numpy as np

# %%
print("Hello ",np.__version__)
# Out:
# Hello  1.23.5

# %%
import matplotlib.pyplot as plt
x = np.linspace(0,10,100)
y = np.sin(x)

plt.plot(x,y)

# %%
np.random.seed(42)
X = np.linspace(0,10,100)
y = np.random.rand(100)

plt.scatter(X,y)

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda
